# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append("../")
from src.data_loader import load_data

df = load_data()
df.head()
# Out:
# ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 12
#       8 from src.data_loader import load_data
#      10 os.chdir("..")
# ---> 12 df = load_data()
#      13 df.head()
#
# File c:\Users\Riccardo\Desktop\computer-science-project\notebooks\..\src\data_loader.py:32, in load_data()
#      25 """
#      26 Load the dataset from the data folder.
#      27
#      28 Returns:
#      29     pd.DataFrame: The dataset.
#      30 """
#      31 if not os.path.exists("data/heart.csv"):
# ---> 32     download_data()
#      33 return pd.read_csv("data/heart.csv")
#
# File c:\Users\Riccardo\Desktop\computer-science-project\notebooks\..\src\data_loader.py:19, in download_data()
#      17 # check if the file exists
#      18 if os.path.exists(source_path):
# ---> 19     shutil.copy(source_path, dest_path) # copy the file to the data folder
# ...
